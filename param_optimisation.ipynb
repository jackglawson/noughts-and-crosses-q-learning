# %%
from scipy.optimize import differential_evolution
from params import StrategyParams, Params
from strategy import LearningStrategy, RandomStrategy
from game import Game

# %%
p = Params(num_epochs=50000,
               explain=False)

# %%
def func(x):
    sp_learning_x = StrategyParams(start_q=x[0],
                                   learning_rate=x[1],
                                   discount_rate=x[2],
                                   epsilon_decay_rate=x[3],
                                   minimum_epsilon=x[4],
                                   next_state_is_predictable=False,
                                   predictive=True,
                                   learning=True,
                                   keep_log=False)
    
    sp_learning_o = StrategyParams(start_q=-x[0],
                                   learning_rate=x[1],
                                   discount_rate=x[2],
                                   epsilon_decay_rate=x[3],
                                   minimum_epsilon=x[4],
                                   next_state_is_predictable=False,
                                   predictive=True,
                                   learning=True,
                                   keep_log=False)
    
    print(sp_learning_x)
    
    strategy_x = LearningStrategy(sp_learning_x)
    strategy_o = LearningStrategy(sp_learning_o)
    strategies = [strategy_x, strategy_o]
    
    for epoch in range(p.num_epochs):
        game = Game(2, strategies)
        game.play(explain=p.explain)
    
    
    N = 5000
    x_win = 0
    o_win = 0
    draw = 0
    strategy_random = RandomStrategy()
    for _ in range(N):
        game = Game(2, [strategy_random, strategy_o])
        game.play(narrate=False, explain=False)
        if game.data.winner == "x":
            x_win += 1
        elif game.data.winner == "o":
            o_win += 1
        else:
            draw += 1
    
    print("x wins: {}, o wins: {}, draws: {}".format(x_win, o_win, draw), "\n")
    
    return o_win + 0.5*draw

# %%
bounds = [(0, 1), (0, 0.5), (0, 1), (0.5, 1), (0, 0.5)]

# %%
differential_evolution(func, bounds)
# Out:
# StrategyParams(start_q=0.49753460130624527, learning_rate=0.34428887946955095, discount_rate=0.15132724725279734, epsilon_decay_rate=0.888637553463036, minimum_epsilon=0.49868388208264564, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1642, o wins: 2693, draws: 665
#
# StrategyParams(start_q=0.5477322595810676, learning_rate=0.281961118234926, discount_rate=0.19643726432358227, epsilon_decay_rate=0.7348880506801824, minimum_epsilon=0.2791927845236568, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1024, o wins: 2848, draws: 1128
#
# StrategyParams(start_q=0.4043769613960632, learning_rate=0.20702282135810043, discount_rate=0.9134123978740905, epsilon_decay_rate=0.6623711942012797, minimum_epsilon=0.1342637933442684, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 783, o wins: 3230, draws: 987
#
# StrategyParams(start_q=0.8693599701904586, learning_rate=0.4001738489338902, discount_rate=0.5066347135401124, epsilon_decay_rate=0.7464569620716127, minimum_epsilon=0.14018537307677825, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 854, o wins: 3263, draws: 883
#
# StrategyParams(start_q=0.012709701821184527, learning_rate=0.41451293905416636, discount_rate=0.3510966486749246, epsilon_decay_rate=0.5559666616850516, minimum_epsilon=0.24076375129695946, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1034, o wins: 2910, draws: 1056
#
# StrategyParams(start_q=0.5182860025336323, learning_rate=0.1421679270052978, discount_rate=0.5970131657608335, epsilon_decay_rate=0.59139001803332, minimum_epsilon=0.21001323013176287, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 873, o wins: 3109, draws: 1018
#
# StrategyParams(start_q=0.4153323503988474, learning_rate=0.007627052842502979, discount_rate=0.18263166390924268, epsilon_decay_rate=0.5329804188329423, minimum_epsilon=0.2156333737882509, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 944, o wins: 2917, draws: 1139
#
# StrategyParams(start_q=0.44425756208561257, learning_rate=0.0761005664311375, discount_rate=0.018015303092880408, epsilon_decay_rate=0.7313409643790851, minimum_epsilon=0.37200741190008957, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1248, o wins: 2769, draws: 983
#
# StrategyParams(start_q=0.22068395055765672, learning_rate=0.12541060275482427, discount_rate=0.8678784554445343, epsilon_decay_rate=0.8663561427288168, minimum_epsilon=0.1295322939567783, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 957, o wins: 2976, draws: 1067
#
# StrategyParams(start_q=0.8088157136786321, learning_rate=0.278706599795611, discount_rate=0.5525910688798156, epsilon_decay_rate=0.9652439587155675, minimum_epsilon=0.08292308327591838, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 745, o wins: 3193, draws: 1062
#
# StrategyParams(start_q=0.9082295988239201, learning_rate=0.25212580816984087, discount_rate=0.6562924942417628, epsilon_decay_rate=0.6535316242423389, minimum_epsilon=0.17920755489373433, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 889, o wins: 3066, draws: 1045
#
# StrategyParams(start_q=0.2783659372210959, learning_rate=0.33199769065488166, discount_rate=0.27245580336682984, epsilon_decay_rate=0.9811742837539821, minimum_epsilon=0.038494233911538306, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1081, o wins: 2882, draws: 1037
#
# StrategyParams(start_q=0.10809636277323792, learning_rate=0.17013786623193736, discount_rate=0.16557367888585062, epsilon_decay_rate=0.8814760793438399, minimum_epsilon=0.27011182596977384, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1013, o wins: 3142, draws: 845
#
# StrategyParams(start_q=0.07209509967940636, learning_rate=0.4580584454025367, discount_rate=0.062361046282882915, epsilon_decay_rate=0.9010789630058837, minimum_epsilon=0.01744332788387007, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 505, o wins: 3382, draws: 1113
#
# StrategyParams(start_q=0.5610914598031128, learning_rate=0.1311045114418589, discount_rate=0.039918590499068984, epsilon_decay_rate=0.9670867946477648, minimum_epsilon=0.049421441459936544, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 859, o wins: 2845, draws: 1296
#
# StrategyParams(start_q=0.15756374687640157, learning_rate=0.11215631436085305, discount_rate=0.8498095291489144, epsilon_decay_rate=0.9506142322816783, minimum_epsilon=0.30056261817498453, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1286, o wins: 2768, draws: 946
#
# StrategyParams(start_q=0.4396308168061428, learning_rate=0.3902166881405858, discount_rate=0.008506287612838503, epsilon_decay_rate=0.9576800728563832, minimum_epsilon=0.39246272595083675, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1371, o wins: 2903, draws: 726
#
# StrategyParams(start_q=0.9339999664768308, learning_rate=0.3128865398045765, discount_rate=0.20407284554775285, epsilon_decay_rate=0.7605023428954367, minimum_epsilon=0.16099349069286123, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 890, o wins: 3275, draws: 835
#
# StrategyParams(start_q=0.9298248744916098, learning_rate=0.11634230588253952, discount_rate=0.7536697752892599, epsilon_decay_rate=0.516611086353721, minimum_epsilon=0.38549963330477893, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1472, o wins: 2604, draws: 924
#
# StrategyParams(start_q=0.35511120490761017, learning_rate=0.4375750119074716, discount_rate=0.667940414489759, epsilon_decay_rate=0.6056887421443133, minimum_epsilon=0.28189294133508486, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1183, o wins: 3039, draws: 778
#
# StrategyParams(start_q=0.3005553702077911, learning_rate=0.4654683450557598, discount_rate=0.7631686552927517, epsilon_decay_rate=0.9253578132937966, minimum_epsilon=0.34110390308201916, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1503, o wins: 2645, draws: 852
#
# StrategyParams(start_q=0.7226872347309077, learning_rate=0.3549378662151109, discount_rate=0.6285117289450511, epsilon_decay_rate=0.8475025961752156, minimum_epsilon=0.032607465072451214, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 713, o wins: 3125, draws: 1162
#
# StrategyParams(start_q=0.4884330853884278, learning_rate=0.3790327373436829, discount_rate=0.36819549542045343, epsilon_decay_rate=0.9888435232533819, minimum_epsilon=0.45852927317427195, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1662, o wins: 2571, draws: 767
#
# StrategyParams(start_q=0.7159820786135674, learning_rate=0.0700202599127443, discount_rate=0.8307602926823681, epsilon_decay_rate=0.7120949076568137, minimum_epsilon=0.4254678606615974, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1500, o wins: 2538, draws: 962
#
# StrategyParams(start_q=0.8654573812486871, learning_rate=0.2622002017246539, discount_rate=0.699991133480296, epsilon_decay_rate=0.566413888372902, minimum_epsilon=0.40107793266378633, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1452, o wins: 2722, draws: 826
#
# StrategyParams(start_q=0.2437168741613307, learning_rate=0.04087826086109608, discount_rate=0.5400294897394188, epsilon_decay_rate=0.9446424860762128, minimum_epsilon=0.026616457907639002, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 766, o wins: 2840, draws: 1394
#
# StrategyParams(start_q=0.7751498157216931, learning_rate=0.44751459962320556, discount_rate=0.803892213170297, epsilon_decay_rate=0.6365334444382147, minimum_epsilon=0.3255170486727179, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1399, o wins: 2869, draws: 732
#
# StrategyParams(start_q=0.33268868847109245, learning_rate=0.17789011375328445, discount_rate=0.10320771943647872, epsilon_decay_rate=0.6704283660758376, minimum_epsilon=0.334701460013494, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1257, o wins: 2567, draws: 1176
#
# StrategyParams(start_q=0.9751869922581681, learning_rate=0.1494385744984799, discount_rate=0.29869264505204335, epsilon_decay_rate=0.6982673421449763, minimum_epsilon=0.18675256797692252, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1076, o wins: 2929, draws: 995
#
# StrategyParams(start_q=0.023206936770249376, learning_rate=0.2914924673779265, discount_rate=0.7323231565995719, epsilon_decay_rate=0.8132246399800696, minimum_epsilon=0.42693428132682837, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1499, o wins: 2713, draws: 788
#
# StrategyParams(start_q=0.08277124743505943, learning_rate=0.20265262123674513, discount_rate=0.8944565351391021, epsilon_decay_rate=0.6151221412710902, minimum_epsilon=0.3558585129699898, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1352, o wins: 2768, draws: 880
#
# StrategyParams(start_q=0.6451319557686382, learning_rate=0.003132696636342608, discount_rate=0.9839017688250272, epsilon_decay_rate=0.8205786114022495, minimum_epsilon=0.41279653689591694, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1467, o wins: 2494, draws: 1039
#
# StrategyParams(start_q=0.6250728359505239, learning_rate=0.09250924261883708, discount_rate=0.8576777665826352, epsilon_decay_rate=0.599431512441101, minimum_epsilon=0.22813886433772304, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1114, o wins: 2847, draws: 1039
#
# StrategyParams(start_q=0.8838655880577952, learning_rate=0.2557447755499269, discount_rate=0.8163190597889599, epsilon_decay_rate=0.938293839668989, minimum_epsilon=0.4383497876134304, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1495, o wins: 2583, draws: 922
#
# StrategyParams(start_q=0.6688691334318965, learning_rate=0.44259088760016563, discount_rate=0.08656161721586086, epsilon_decay_rate=0.927660715471091, minimum_epsilon=0.4794676418704467, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1568, o wins: 2576, draws: 856
#
# StrategyParams(start_q=0.19913118944543734, learning_rate=0.05802010461401236, discount_rate=0.9305202855967405, epsilon_decay_rate=0.7532697725262105, minimum_epsilon=0.10805361252559814, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 693, o wins: 2987, draws: 1320
#
# StrategyParams(start_q=0.539837481681854, learning_rate=0.10335789422077674, discount_rate=0.7441758347107807, epsilon_decay_rate=0.8770428179261546, minimum_epsilon=0.41791435909143404, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1372, o wins: 2840, draws: 788
#
# StrategyParams(start_q=0.12867957251557283, learning_rate=0.39798364981248063, discount_rate=0.3189527839732541, epsilon_decay_rate=0.6763117850450425, minimum_epsilon=0.15738957968894088, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 704, o wins: 3547, draws: 749
#
# StrategyParams(start_q=0.6832474079892022, learning_rate=0.01772078047181508, discount_rate=0.880302453318246, epsilon_decay_rate=0.8686063221276881, minimum_epsilon=0.4821855486538237, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1697, o wins: 2324, draws: 979
#
# StrategyParams(start_q=0.7006368176947007, learning_rate=0.039324390711823864, discount_rate=0.14405389524960122, epsilon_decay_rate=0.5261404222102075, minimum_epsilon=0.11893515102751218, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1329, o wins: 2815, draws: 856
#
# StrategyParams(start_q=0.5269949704071324, learning_rate=0.36586032076723346, discount_rate=0.3323459475120672, epsilon_decay_rate=0.9118474040804774, minimum_epsilon=0.2543197613117312, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 900, o wins: 3232, draws: 868
#
# StrategyParams(start_q=0.043143145008168404, learning_rate=0.02998652759047299, discount_rate=0.4923771021026557, epsilon_decay_rate=0.6482782362134453, minimum_epsilon=0.07598804308383217, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 309, o wins: 3788, draws: 903
#
# StrategyParams(start_q=0.9601048677938617, learning_rate=0.05093048923084453, discount_rate=0.646623490084244, epsilon_decay_rate=0.5089686767598454, minimum_epsilon=0.2962585326140532, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1332, o wins: 2601, draws: 1067
#
# StrategyParams(start_q=0.7466463643662787, learning_rate=0.19614505341063843, discount_rate=0.9902500146485949, epsilon_decay_rate=0.7544639429165962, minimum_epsilon=0.0453244706784629, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1341, o wins: 2564, draws: 1095
#
# StrategyParams(start_q=0.20382137735121475, learning_rate=0.3013489438019195, discount_rate=0.9720660273966867, epsilon_decay_rate=0.6244021219380917, minimum_epsilon=0.12435486702877246, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 915, o wins: 3194, draws: 891
#
# StrategyParams(start_q=0.18086397053365422, learning_rate=0.37114520566377734, discount_rate=0.412224782353021, epsilon_decay_rate=0.5530101564930278, minimum_epsilon=0.15167559325767424, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 771, o wins: 2985, draws: 1244
#
# StrategyParams(start_q=0.9996629686797245, learning_rate=0.3264484502435769, discount_rate=0.683423278150526, epsilon_decay_rate=0.7037075349648929, minimum_epsilon=0.09053791031661282, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 750, o wins: 3067, draws: 1183
#
# StrategyParams(start_q=0.611717749204169, learning_rate=0.3866630473229207, discount_rate=0.046976083536071744, epsilon_decay_rate=0.642567554741782, minimum_epsilon=0.010835465079376577, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 406, o wins: 3646, draws: 948
#
# StrategyParams(start_q=0.3415669242859728, learning_rate=0.21994282927602182, discount_rate=0.24410468870299962, epsilon_decay_rate=0.6109869531453547, minimum_epsilon=0.3740572198170641, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1322, o wins: 2702, draws: 976
#
# StrategyParams(start_q=0.7525822009456918, learning_rate=0.22428661468784478, discount_rate=0.43366266927517877, epsilon_decay_rate=0.792661354040591, minimum_epsilon=0.31690095106471056, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1231, o wins: 2708, draws: 1061
#
# StrategyParams(start_q=0.7904871248115068, learning_rate=0.40943233955107394, discount_rate=0.9497028953856657, epsilon_decay_rate=0.8572713451764999, minimum_epsilon=0.44423658238468033, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1663, o wins: 2675, draws: 662
#
# StrategyParams(start_q=0.23673427460975138, learning_rate=0.08301187338841576, discount_rate=0.9346000713855338, epsilon_decay_rate=0.7247889345745209, minimum_epsilon=0.311224894931868, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1172, o wins: 2937, draws: 891
#
# StrategyParams(start_q=0.37032901152117165, learning_rate=0.063425400230055, discount_rate=0.33726241818394087, epsilon_decay_rate=0.6277552071487283, minimum_epsilon=0.06019959209146125, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 464, o wins: 3184, draws: 1352
#
# StrategyParams(start_q=0.25651026340684513, learning_rate=0.31960716603717787, discount_rate=0.12519597798041465, epsilon_decay_rate=0.505301670253032, minimum_epsilon=0.06871052039780917, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 302, o wins: 3399, draws: 1299
#
# StrategyParams(start_q=0.9598772672349617, learning_rate=0.49430440701264083, discount_rate=0.39138818262821096, epsilon_decay_rate=0.8947487542551187, minimum_epsilon=0.18006063777763753, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 907, o wins: 3182, draws: 911
#
# StrategyParams(start_q=0.30685195579957075, learning_rate=0.42469966580640484, discount_rate=0.7740497178618536, epsilon_decay_rate=0.9748654764131459, minimum_epsilon=0.2230571956291939, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1669, o wins: 2440, draws: 891
#
# StrategyParams(start_q=0.8985178614991968, learning_rate=0.1924632320509186, discount_rate=0.6016909251047166, epsilon_decay_rate=0.8324984701938886, minimum_epsilon=0.4683337130844479, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1573, o wins: 2561, draws: 866
#
# StrategyParams(start_q=0.8298769947720459, learning_rate=0.2671053710540594, discount_rate=0.253345172355253, epsilon_decay_rate=0.692314369839705, minimum_epsilon=0.19976418946915606, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1093, o wins: 2734, draws: 1173
#
# StrategyParams(start_q=0.47831256895470714, learning_rate=0.4929300133463485, discount_rate=0.37891672565014645, epsilon_decay_rate=0.8019286585676297, minimum_epsilon=0.23628799842812556, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 915, o wins: 3252, draws: 833
#
# StrategyParams(start_q=0.848981298598691, learning_rate=0.097755771853092, discount_rate=0.512907963027586, epsilon_decay_rate=0.571104147444552, minimum_epsilon=0.2878721392012883, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1232, o wins: 2747, draws: 1021
#
# StrategyParams(start_q=0.3952785913700537, learning_rate=0.1357094230921137, discount_rate=0.22604385124182352, epsilon_decay_rate=0.7801202687179241, minimum_epsilon=0.251633419428036, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1017, o wins: 3131, draws: 852
#
# StrategyParams(start_q=0.13898090279199987, learning_rate=0.18185128319441582, discount_rate=0.4740028819587614, epsilon_decay_rate=0.9191969068746402, minimum_epsilon=0.3984196199295937, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1373, o wins: 2919, draws: 708
#
# StrategyParams(start_q=0.4622815389126646, learning_rate=0.3512101049671067, discount_rate=0.44505018851941663, epsilon_decay_rate=0.7730897212475891, minimum_epsilon=0.26659874565339015, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1092, o wins: 3000, draws: 908
#
# StrategyParams(start_q=0.03555106929063534, learning_rate=0.15575490446062387, discount_rate=0.5714762809729667, epsilon_decay_rate=0.5380220172274301, minimum_epsilon=0.46166572352180246, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1462, o wins: 2727, draws: 811
#
# StrategyParams(start_q=0.6631077774459432, learning_rate=0.4313734642367368, discount_rate=0.5788284070116517, epsilon_decay_rate=0.5789099053269373, minimum_epsilon=0.3324768767218768, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1250, o wins: 2908, draws: 842
#
# StrategyParams(start_q=0.5860054053310098, learning_rate=0.2266857819649412, discount_rate=0.5221026316144095, epsilon_decay_rate=0.8389985427072826, minimum_epsilon=0.004268170777284058, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 833, o wins: 3182, draws: 985
#
# StrategyParams(start_q=0.06528051632346638, learning_rate=0.3339902657894752, discount_rate=0.07137202051387576, epsilon_decay_rate=0.5821045200018431, minimum_epsilon=0.17206484098521088, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 743, o wins: 3195, draws: 1062
#
# StrategyParams(start_q=0.37857201532145374, learning_rate=0.2339208350328046, discount_rate=0.7917988337791507, epsilon_decay_rate=0.8184919317098268, minimum_epsilon=0.48875198804046405, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1586, o wins: 2550, draws: 864
#
# StrategyParams(start_q=0.2819547726465989, learning_rate=0.24131004733740577, discount_rate=0.42307396971217837, epsilon_decay_rate=0.7160240998016927, minimum_epsilon=0.447652949758532, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1410, o wins: 2781, draws: 809
#
# StrategyParams(start_q=0.10171475550358278, learning_rate=0.16132763314178372, discount_rate=0.2283086928006433, epsilon_decay_rate=0.7953901964762325, minimum_epsilon=0.09772520369426896, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 492, o wins: 3366, draws: 1142
#
# StrategyParams(start_q=0.7724682885195481, learning_rate=0.4735487280733173, discount_rate=0.2890937754834353, epsilon_decay_rate=0.6800479925044572, minimum_epsilon=0.057665436642734075, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 464, o wins: 3781, draws: 755
#
# StrategyParams(start_q=0.8167470160235808, learning_rate=0.47135449513991995, discount_rate=0.11419094189610113, epsilon_decay_rate=0.5438200853200829, minimum_epsilon=0.10203063568121373, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 902, o wins: 3207, draws: 891
#
# StrategyParams(start_q=0.6305899615320175, learning_rate=0.48013045444614444, discount_rate=0.6187420358646782, epsilon_decay_rate=0.7791705490342176, minimum_epsilon=0.2019571148500115, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 980, o wins: 3181, draws: 839
#
# StrategyParams(start_q=0.1664185980033921, learning_rate=0.023307730834111695, discount_rate=0.717052023779069, epsilon_decay_rate=0.8429242714949023, minimum_epsilon=0.3531524707412011, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1325, o wins: 2624, draws: 1051
#
# StrategyParams(start_q=0.5912934540398188, learning_rate=0.29734480206632447, discount_rate=0.4632489747745379, epsilon_decay_rate=0.9940504762806317, minimum_epsilon=0.3612375879277068, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1809, o wins: 2470, draws: 721
#
# StrategyParams(start_q=0.49591235405445033, learning_rate=0.01772078047181508, discount_rate=0.08885249808596407, epsilon_decay_rate=0.8686063221276881, minimum_epsilon=0.4821855486538237, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1710, o wins: 2398, draws: 892
#
# StrategyParams(start_q=0.5477322595810676, learning_rate=0.4766775965761991, discount_rate=0.6091713420281619, epsilon_decay_rate=0.8567054187759399, minimum_epsilon=0.2791927845236568, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 966, o wins: 3261, draws: 773
#
# StrategyParams(start_q=0.2499254173815184, learning_rate=0.14541598005391698, discount_rate=0.9134123978740905, epsilon_decay_rate=0.6890106704660742, minimum_epsilon=0.1342637933442684, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 975, o wins: 2765, draws: 1260
#
# StrategyParams(start_q=0.9980285495211677, learning_rate=0.02298604350980271, discount_rate=0.5066347135401124, epsilon_decay_rate=0.961753825449778, minimum_epsilon=0.14018537307677825, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1061, o wins: 2709, draws: 1230
#
# StrategyParams(start_q=0.5167648829414685, learning_rate=0.25938222210112766, discount_rate=0.18186145590111102, epsilon_decay_rate=0.5704886579448278, minimum_epsilon=0.41319602585745435, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1433, o wins: 2647, draws: 920
#
# StrategyParams(start_q=0.4094558747524277, learning_rate=0.49257886761395697, discount_rate=0.7425295957801697, epsilon_decay_rate=0.5872805703341804, minimum_epsilon=0.21987643115863104, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1085, o wins: 3187, draws: 728
#
# StrategyParams(start_q=0.4153323503988474, learning_rate=0.007627052842502979, discount_rate=0.7952051087900546, epsilon_decay_rate=0.630177043464696, minimum_epsilon=0.28235597814859537, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1077, o wins: 2768, draws: 1155
#
# StrategyParams(start_q=0.22523603657828695, learning_rate=0.06894125850511396, discount_rate=0.9146263073123686, epsilon_decay_rate=0.6838083707853873, minimum_epsilon=0.37200741190008957, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1314, o wins: 2730, draws: 956
#
# StrategyParams(start_q=0.8524783029347915, learning_rate=0.19868332594205682, discount_rate=0.5270516388729927, epsilon_decay_rate=0.9075767811723763, minimum_epsilon=0.27107062628865297, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1071, o wins: 2931, draws: 998
#
# StrategyParams(start_q=0.8088157136786321, learning_rate=0.278706599795611, discount_rate=0.5236291614806106, epsilon_decay_rate=0.9652439587155675, minimum_epsilon=0.33527632950261854, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1340, o wins: 2841, draws: 819
#
# StrategyParams(start_q=0.322451343028002, learning_rate=0.022902591876544864, discount_rate=0.3355149113909405, epsilon_decay_rate=0.8927555004468253, minimum_epsilon=0.17920755489373433, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 897, o wins: 3020, draws: 1083
#
# StrategyParams(start_q=0.31938603917980946, learning_rate=0.08911554546367312, discount_rate=0.9700121084803076, epsilon_decay_rate=0.5587637269803205, minimum_epsilon=0.4332491175908991, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1382, o wins: 2851, draws: 767
#
# StrategyParams(start_q=0.4306303493223821, learning_rate=0.28909274044008737, discount_rate=0.8904588429678248, epsilon_decay_rate=0.7515292951489478, minimum_epsilon=0.26703051918093546, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1274, o wins: 3001, draws: 725
#
# StrategyParams(start_q=0.07209509967940636, learning_rate=0.44882876105903846, discount_rate=0.9211587342851199, epsilon_decay_rate=0.7325977074041458, minimum_epsilon=0.01744332788387007, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 942, o wins: 3153, draws: 905
#
# StrategyParams(start_q=0.9884603638141128, learning_rate=0.17368906263889322, discount_rate=0.039918590499068984, epsilon_decay_rate=0.9670867946477648, minimum_epsilon=0.3862132244816897, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1531, o wins: 2508, draws: 961
#
# StrategyParams(start_q=0.8766761929760559, learning_rate=0.11215631436085305, discount_rate=0.6340687492916626, epsilon_decay_rate=0.726603016784761, minimum_epsilon=0.15511382218481434, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1082, o wins: 2951, draws: 967
#
# StrategyParams(start_q=0.4747663149574872, learning_rate=0.3902166881405858, discount_rate=0.008506287612838503, epsilon_decay_rate=0.6483700985820541, minimum_epsilon=0.39246272595083675, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1190, o wins: 2917, draws: 893
#
# StrategyParams(start_q=0.31035480792222914, learning_rate=0.17451665137163622, discount_rate=0.782080893995815, epsilon_decay_rate=0.8128855279231495, minimum_epsilon=0.24502979773549782, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1193, o wins: 2733, draws: 1074
#
# StrategyParams(start_q=0.9298248744916098, learning_rate=0.018018250710902323, discount_rate=0.7536697752892599, epsilon_decay_rate=0.516611086353721, minimum_epsilon=0.2056938470676028, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1281, o wins: 2635, draws: 1084
#
# StrategyParams(start_q=0.714842875326186, learning_rate=0.4375750119074716, discount_rate=0.6444721679360192, epsilon_decay_rate=0.9561690814127402, minimum_epsilon=0.33733670283921574, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1335, o wins: 2755, draws: 910
#
# StrategyParams(start_q=0.6646239178479555, learning_rate=0.40023309426273435, discount_rate=0.6015238075445347, epsilon_decay_rate=0.6007186689428528, minimum_epsilon=0.34374716122685245, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1345, o wins: 2803, draws: 852
#
# StrategyParams(start_q=0.7226872347309077, learning_rate=0.45815393810257315, discount_rate=0.6285117289450511, epsilon_decay_rate=0.7130086352562078, minimum_epsilon=0.43989563864863457, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1459, o wins: 2699, draws: 842
#
# StrategyParams(start_q=0.550681741832642, learning_rate=0.40649466152058367, discount_rate=0.3879521944213823, epsilon_decay_rate=0.9008340664418653, minimum_epsilon=0.30257940762187974, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1198, o wins: 2828, draws: 974
#
# StrategyParams(start_q=0.5812457556069718, learning_rate=0.0700202599127443, discount_rate=0.05297388326053354, epsilon_decay_rate=0.7761695173470359, minimum_epsilon=0.4254678606615974, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1634, o wins: 2492, draws: 874
#
# StrategyParams(start_q=0.8654573812486871, learning_rate=0.06473819849231632, discount_rate=0.1969183434988897, epsilon_decay_rate=0.9206549591617272, minimum_epsilon=0.3527746523020767, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1467, o wins: 2703, draws: 830
#
# StrategyParams(start_q=0.2437168741613307, learning_rate=0.04087826086109608, discount_rate=0.6133891460764958, epsilon_decay_rate=0.941941509408295, minimum_epsilon=0.4509143811622894, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1579, o wins: 2557, draws: 864
#
# StrategyParams(start_q=0.6646983676097212, learning_rate=0.44751459962320556, discount_rate=0.763580775812761, epsilon_decay_rate=0.6365334444382147, minimum_epsilon=0.31142917171799356, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1350, o wins: 2879, draws: 771
#
# StrategyParams(start_q=0.8295336517916816, learning_rate=0.04491994145788247, discount_rate=0.3661268171085731, epsilon_decay_rate=0.8881006836032018, minimum_epsilon=0.043877031917319564, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 984, o wins: 2807, draws: 1209
#
# StrategyParams(start_q=0.53077278762577, learning_rate=0.10025535414166081, discount_rate=0.5674013456877229, epsilon_decay_rate=0.9221093652742312, minimum_epsilon=0.2584259128324449, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1059, o wins: 2845, draws: 1096
#
# StrategyParams(start_q=0.4261359539798307, learning_rate=0.12810073612449685, discount_rate=0.7323231565995719, epsilon_decay_rate=0.8287189630236604, minimum_epsilon=0.41112054206725895, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1377, o wins: 2625, draws: 998
#
# StrategyParams(start_q=0.9487783737133388, learning_rate=0.21383607774069546, discount_rate=0.9263143565584394, epsilon_decay_rate=0.6151221412710902, minimum_epsilon=0.31397509665297363, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1319, o wins: 2746, draws: 935
#
# StrategyParams(start_q=0.9370745072354572, learning_rate=0.003132696636342608, discount_rate=0.3318062855441314, epsilon_decay_rate=0.9421310840567106, minimum_epsilon=0.26194391535331424, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 2318, o wins: 1858, draws: 824
#
# StrategyParams(start_q=0.7545647792844781, learning_rate=0.38922865388308664, discount_rate=0.6198700902577405, epsilon_decay_rate=0.599431512441101, minimum_epsilon=0.4926880179106056, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1571, o wins: 2650, draws: 779
#
# StrategyParams(start_q=0.8838655880577952, learning_rate=0.403314368339806, discount_rate=0.8163190597889599, epsilon_decay_rate=0.938293839668989, minimum_epsilon=0.4383497876134304, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1626, o wins: 2652, draws: 722
#
# StrategyParams(start_q=0.7020984142238889, learning_rate=0.44259088760016563, discount_rate=0.9118270707222971, epsilon_decay_rate=0.963714748553014, minimum_epsilon=0.4794676418704467, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1929, o wins: 2338, draws: 733
#
# StrategyParams(start_q=0.6349831693097837, learning_rate=0.007487454365742718, discount_rate=0.4722959460303763, epsilon_decay_rate=0.7532697725262105, minimum_epsilon=0.10805361252559814, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1004, o wins: 2673, draws: 1323
#
# StrategyParams(start_q=0.1412074791485266, learning_rate=0.3088405364679887, discount_rate=0.2541337149578615, epsilon_decay_rate=0.8264772739047745, minimum_epsilon=0.25138778482603247, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 983, o wins: 3180, draws: 837
#
# StrategyParams(start_q=0.2658209362072371, learning_rate=0.19610882820308, discount_rate=0.7670299563572577, epsilon_decay_rate=0.7997885771047819, minimum_epsilon=0.17854213259690704, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 858, o wins: 3228, draws: 914
#
# StrategyParams(start_q=0.27912208286704354, learning_rate=0.34428887946955095, discount_rate=0.15132724725279734, epsilon_decay_rate=0.8141094040478112, minimum_epsilon=0.49868388208264564, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1651, o wins: 2567, draws: 782
#
# StrategyParams(start_q=0.8667850967750756, learning_rate=0.18824081725715025, discount_rate=0.7247477540837988, epsilon_decay_rate=0.9823980327061932, minimum_epsilon=0.44444122616260884, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1641, o wins: 2597, draws: 762
#
# StrategyParams(start_q=0.5269949704071324, learning_rate=0.22336575045951967, discount_rate=0.5572853617744915, epsilon_decay_rate=0.8407468421623583, minimum_epsilon=0.2349162288795875, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 967, o wins: 3183, draws: 850
#
# StrategyParams(start_q=0.043143145008168404, learning_rate=0.3286924976156849, discount_rate=0.011704913822047414, epsilon_decay_rate=0.8718965569013686, minimum_epsilon=0.23388950943188927, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1017, o wins: 3032, draws: 951
#
# StrategyParams(start_q=0.6108772894608099, learning_rate=0.28615343820042893, discount_rate=0.646623490084244, epsilon_decay_rate=0.722062585418357, minimum_epsilon=0.2962585326140532, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1309, o wins: 2683, draws: 1008
#
# StrategyParams(start_q=0.71042766264537, learning_rate=0.061186716099833394, discount_rate=0.27303747319557264, epsilon_decay_rate=0.8457051107366456, minimum_epsilon=0.04607893620644926, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 904, o wins: 2625, draws: 1471
#
# StrategyParams(start_q=0.9062413573714978, learning_rate=0.3013489438019195, discount_rate=0.21733763147704982, epsilon_decay_rate=0.9339199377023188, minimum_epsilon=0.24537359099236622, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1156, o wins: 2832, draws: 1012
#
# StrategyParams(start_q=0.4949586107813343, learning_rate=0.37114520566377734, discount_rate=0.6000929424411785, epsilon_decay_rate=0.5530101564930278, minimum_epsilon=0.23779784196392986, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 885, o wins: 3048, draws: 1067
#
# StrategyParams(start_q=0.3868498996182952, learning_rate=0.4667484644070219, discount_rate=0.7166250102730893, epsilon_decay_rate=0.9200564004173772, minimum_epsilon=0.24683555570179794, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1176, o wins: 3011, draws: 813
#
# StrategyParams(start_q=0.611717749204169, learning_rate=0.06456157136207397, discount_rate=0.37284457900756196, epsilon_decay_rate=0.9337922317403141, minimum_epsilon=0.35398934737849574, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1332, o wins: 2711, draws: 957
#
# StrategyParams(start_q=0.7388266174680035, learning_rate=0.21994282927602182, discount_rate=0.6061753157089269, epsilon_decay_rate=0.7302573032935024, minimum_epsilon=0.42649917654789116, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1499, o wins: 2715, draws: 786
#
# StrategyParams(start_q=0.8122194520472052, learning_rate=0.07555273316771177, discount_rate=0.43366266927517877, epsilon_decay_rate=0.792661354040591, minimum_epsilon=0.31690095106471056, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1348, o wins: 2675, draws: 977
#
# StrategyParams(start_q=0.6049145501864195, learning_rate=0.27428812279060405, discount_rate=0.9497028953856657, epsilon_decay_rate=0.7935680150807025, minimum_epsilon=0.44423658238468033, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1647, o wins: 2523, draws: 830
#
# StrategyParams(start_q=0.23673427460975138, learning_rate=0.3454550311908009, discount_rate=0.7535119926895184, epsilon_decay_rate=0.7247889345745209, minimum_epsilon=0.311224894931868, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1208, o wins: 3096, draws: 696
#
# StrategyParams(start_q=0.12413640456527342, learning_rate=0.033888526779575434, discount_rate=0.33726241818394087, epsilon_decay_rate=0.7002214152609917, minimum_epsilon=0.10816430563885568, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 608, o wins: 3125, draws: 1267
#
# StrategyParams(start_q=0.25651026340684513, learning_rate=0.04651617015676718, discount_rate=0.46404767736734664, epsilon_decay_rate=0.9145792694915742, minimum_epsilon=0.06871052039780917, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 600, o wins: 3218, draws: 1182
#
# StrategyParams(start_q=0.6001494259247919, learning_rate=0.4060967611240159, discount_rate=0.4701910449903727, epsilon_decay_rate=0.8689071582172851, minimum_epsilon=0.34953932151226375, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1364, o wins: 2687, draws: 949
#
# StrategyParams(start_q=0.466094776725018, learning_rate=0.45818110974881704, discount_rate=0.21910434744436935, epsilon_decay_rate=0.9468080579295864, minimum_epsilon=0.38453659336801116, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1230, o wins: 2869, draws: 901
#
# StrategyParams(start_q=0.9946741530491569, learning_rate=0.23756663449387977, discount_rate=0.695984717910267, epsilon_decay_rate=0.7750448376666608, minimum_epsilon=0.484851576380142, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1568, o wins: 2613, draws: 819
#
# StrategyParams(start_q=0.7773741043820134, learning_rate=0.3209794109068931, discount_rate=0.30661162791095087, epsilon_decay_rate=0.9604589584841866, minimum_epsilon=0.4085535424468152, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1405, o wins: 2780, draws: 815
#
# StrategyParams(start_q=0.7174199837058707, learning_rate=0.03273992683551963, discount_rate=0.37891672565014645, epsilon_decay_rate=0.8649946307356572, minimum_epsilon=0.2706000362350068, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1361, o wins: 2381, draws: 1258
#
# StrategyParams(start_q=0.41432237149089246, learning_rate=0.3747349862460192, discount_rate=0.9142664098959118, epsilon_decay_rate=0.571104147444552, minimum_epsilon=0.23430197493018687, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1015, o wins: 3253, draws: 732
#
# StrategyParams(start_q=0.3952785913700537, learning_rate=0.3252403612451459, discount_rate=0.025725161686732334, epsilon_decay_rate=0.976922392230924, minimum_epsilon=0.39660806242419505, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1563, o wins: 2583, draws: 854
#
# StrategyParams(start_q=0.45691940381499496, learning_rate=0.4599043943120277, discount_rate=0.5287351089547939, epsilon_decay_rate=0.679795200231361, minimum_epsilon=0.24285548790269343, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 961, o wins: 3035, draws: 1004
#
# StrategyParams(start_q=0.4622815389126646, learning_rate=0.012704184268410107, discount_rate=0.9065558909443605, epsilon_decay_rate=0.7947613335102335, minimum_epsilon=0.36342231380709455, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1260, o wins: 2759, draws: 981
#
# StrategyParams(start_q=0.7651072190410326, learning_rate=0.23913946105054348, discount_rate=0.30660888698703026, epsilon_decay_rate=0.5109846190841187, minimum_epsilon=0.46166572352180246, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1581, o wins: 2501, draws: 918
#
# StrategyParams(start_q=0.1545678337177162, learning_rate=0.2749448830937405, discount_rate=0.4605844294485423, epsilon_decay_rate=0.866575036241441, minimum_epsilon=0.3324768767218768, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1221, o wins: 3061, draws: 718
#
# StrategyParams(start_q=0.30431294407781184, learning_rate=0.1507567478781469, discount_rate=0.5221026316144095, epsilon_decay_rate=0.8389985427072826, minimum_epsilon=0.1729821122901556, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 798, o wins: 3297, draws: 905
#
# StrategyParams(start_q=0.8837601613001069, learning_rate=0.3339902657894752, discount_rate=0.07137202051387576, epsilon_decay_rate=0.7634478633147457, minimum_epsilon=0.4244974785545508, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1388, o wins: 2704, draws: 908
#
# StrategyParams(start_q=0.9403136596038411, learning_rate=0.45469893923167193, discount_rate=0.3392328631683922, epsilon_decay_rate=0.7923452194499337, minimum_epsilon=0.2822623883176187, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 913, o wins: 3195, draws: 892
#
# StrategyParams(start_q=0.23082752666338058, learning_rate=0.09245073949115773, discount_rate=0.3608335241270741, epsilon_decay_rate=0.7160240998016927, minimum_epsilon=0.026094956680744186, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 479, o wins: 3132, draws: 1389
#
# StrategyParams(start_q=0.10171475550358278, learning_rate=0.38011828839762, discount_rate=0.2283086928006433, epsilon_decay_rate=0.7953901964762325, minimum_epsilon=0.25696978490792727, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 891, o wins: 3246, draws: 863
#
# StrategyParams(start_q=0.7199904854529761, learning_rate=0.025445318836109565, discount_rate=0.4678407232743811, epsilon_decay_rate=0.7181015817284697, minimum_epsilon=0.07180895579516353, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 944, o wins: 2714, draws: 1342
#
# StrategyParams(start_q=0.5397445623283962, learning_rate=0.3132447270409566, discount_rate=0.28934569126443554, epsilon_decay_rate=0.6516947504112764, minimum_epsilon=0.2850197403718878, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1013, o wins: 3073, draws: 914
#
# StrategyParams(start_q=0.31635387209426324, learning_rate=0.18158130700233502, discount_rate=0.6187420358646782, epsilon_decay_rate=0.8105043260977924, minimum_epsilon=0.1848207389578943, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 963, o wins: 3089, draws: 948
#
# StrategyParams(start_q=0.26679698109271865, learning_rate=0.023307730834111695, discount_rate=0.16938359036492778, epsilon_decay_rate=0.6643602111943175, minimum_epsilon=0.3531524707412011, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 1308, o wins: 2732, draws: 960
#
# StrategyParams(start_q=0.7845349744360139, learning_rate=0.15752121062863217, discount_rate=0.4632489747745379, epsilon_decay_rate=0.6751313461606019, minimum_epsilon=0.15825855042505568, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-2ecfca1048f6> in <module>
# ----> 1 differential_evolution(func, bounds)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\scipy\optimize\_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints)
#     306                                      workers=workers,
#     307                                      constraints=constraints) as solver:
# --> 308         ret = solver.solve()
#     309
#     310     return ret
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\scipy\optimize\_differentialevolution.py in solve(self)
#     757             # evolve the population by a generation
#     758             try:
# --> 759                 next(self)
#     760             except StopIteration:
#     761                 warning_flag = True
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\scipy\optimize\_differentialevolution.py in __next__(self)
#    1073                     feasible = True
#    1074                     cv = np.atleast_2d([0.])
# -> 1075                     energy = self.func(parameters)
#    1076                     self._nfev += 1
#    1077
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\scipy\optimize\_differentialevolution.py in __call__(self, x)
#    1259
#    1260     def __call__(self, x):
# -> 1261         return self.f(x, *self.args)
#    1262
#    1263
#
# <ipython-input-30-5bfc8e4bd98f> in func(x)
#      28     for epoch in range(p.num_epochs):
#      29         game = Game(2, strategies)
# ---> 30         game.play(explain=p.explain)
#      31
#      32
#
# ~\Desktop\python_work\noughts_and_crosses\game.py in play(self, explain, narrate)
#      33             self.data = propagate_game(self.data, action)
#      34             self.strategies[p].return_result(self.data)
# ---> 35             self.log.append(deepcopy(self.data))
#      36
#      37             if narrate:
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     261     deep = memo is not None
#     262     if deep and args:
# --> 263         args = (deepcopy(arg, memo) for arg in args)
#     264     y = func(*args)
#     265     if deep:
#
# KeyboardInterrupt:

# %% [markdown]
# # Best Params:
#
# StrategyParams(start_q=0.23082752666338058, learning_rate=0.09245073949115773, discount_rate=0.3608335241270741, epsilon_decay_rate=0.7160240998016927, minimum_epsilon=0.026094956680744186, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 479, o wins: 3132, draws: 1389
#
#
# StrategyParams(start_q=0.10171475550358278, learning_rate=0.16132763314178372, discount_rate=0.2283086928006433, epsilon_decay_rate=0.7953901964762325, minimum_epsilon=0.09772520369426896, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 492, o wins: 3366, draws: 1142
#
# StrategyParams(start_q=0.7724682885195481, learning_rate=0.4735487280733173, discount_rate=0.2890937754834353, epsilon_decay_rate=0.6800479925044572, minimum_epsilon=0.057665436642734075, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 464, o wins: 3781, draws: 755
#
# StrategyParams(start_q=0.37032901152117165, learning_rate=0.063425400230055, discount_rate=0.33726241818394087, epsilon_decay_rate=0.6277552071487283, minimum_epsilon=0.06019959209146125, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 464, o wins: 3184, draws: 1352
#
# StrategyParams(start_q=0.25651026340684513, learning_rate=0.31960716603717787, discount_rate=0.12519597798041465, epsilon_decay_rate=0.505301670253032, minimum_epsilon=0.06871052039780917, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 302, o wins: 3399, draws: 1299
#
# StrategyParams(start_q=0.043143145008168404, learning_rate=0.02998652759047299, discount_rate=0.4923771021026557, epsilon_decay_rate=0.6482782362134453, minimum_epsilon=0.07598804308383217, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 309, o wins: 3788, draws: 903
#
# StrategyParams(start_q=0.611717749204169, learning_rate=0.3866630473229207, discount_rate=0.046976083536071744, epsilon_decay_rate=0.642567554741782, minimum_epsilon=0.010835465079376577, next_state_is_predictable=False, predictive=True, learning=True, keep_log=False)
# x wins: 406, o wins: 3646, draws: 948

# %%
sp_learning_x = StrategyParams(start_q=0.3,
                               learning_rate=0.1,
                               discount_rate=0.7,
                               epsilon_decay_rate=0.0,
                               minimum_epsilon=0.4,
                               next_state_is_predictable=False,
                               predictive=True,
                               learning=True,
                               keep_log=True)
